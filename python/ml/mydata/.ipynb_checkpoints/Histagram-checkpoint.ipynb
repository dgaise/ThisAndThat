# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
###
# import matplotlib.pyplot as plt
#
# plt.hist([1, 2, 2, 3, 3, 3])
# plt.show()
###

# %%
my_df = pd.DataFrame(randn(25, 4), columns=["Mon","Tue","Wed","Thur"])
my_df
# Out:
#          Mon       Tue       Wed      Thur
# 0  -0.392266 -0.113671 -1.574995  0.847040
# 1   1.515379 -0.547967 -0.096403 -0.737328
# 2  -1.112134 -0.389004  0.859631  1.921137
# 3   0.629382 -0.543689 -0.355633 -0.218604
# 4  -2.580335  1.056129  2.457954 -0.729133
# 5  -0.792135 -0.146319  0.908309 -0.669747
# 6   0.366430  1.192993  0.195346 -0.224691
# 7   2.521741 -0.630225  0.317765  0.003325
# 8  -0.991864  0.202695 -0.768153 -1.146279
# 9  -0.029040  0.799318 -1.414564  1.380426
# 10 -0.599994  0.056558  0.447989 -0.412627
# 11  0.670485  1.371679  0.767654 -1.312126
# 12  0.798883 -0.337790  1.029453 -0.006706
# 13 -0.882544 -0.346216 -3.052798  0.046820
# 14 -0.878473 -0.038498  1.050822 -0.667670
# 15  0.627310  0.266424  0.513284 -1.209925
# 16 -0.644948 -0.749936  1.863541 -0.490584
# 17  0.438245  0.346901  0.052486 -0.045047
# 18  0.282811  0.103966 -1.223363  0.593227
# 19 -1.485043 -0.372737  0.370749  1.279035
# 20  1.008865  1.597315  1.605048  0.521775
# 21 -0.957448  0.161241 -2.566222  0.834348
# 22  0.255348 -1.852973  0.410290 -1.510100
# 23 -0.542413  0.313446 -1.150409  0.693885
# 24  0.632687 -0.491318 -0.805926  1.012385

# %%
my_df.hist(bins=10,figsize=(6,8), legend=True)
# Out:
# array([[<Axes: title={'center': 'Mon'}>, <Axes: title={'center': 'Tue'}>],
#        [<Axes: title={'center': 'Wed'}>,
#         <Axes: title={'center': 'Thur'}>]], dtype=object)

# %%
my_df[["Tue","Wed"]].hist(bins=50,legend=True, grid=False)
# Out:
# array([[<Axes: title={'center': 'Tue'}>, <Axes: title={'center': 'Wed'}>]],
#       dtype=object)

# %%
my_df.Tue.plot(kind="hist") # No bars
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df.abs().plot(kind="area") # area
# Out:
# <Axes: >

# %%
my_df.abs().plot(kind="area", alpha=0.4, title="My plot") # less bright, with title
# Out:
# <Axes: title={'center': 'My plot'}>

# %%
my_df[["Mon","Thur"]].abs().plot(kind="area", 
                                 alpha=0.4,   # less bright, with title 
                                 title="My plot", 
                                 grid=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 my_df[["Mon","Thur"]].plot(kind="area",
#       2                                  alpha=0.4,   # less bright, with title
#       3                                  title="My plot",
#       4                                  grid=True)
#
# File ~/ThisAndThat/python/ml/mydata/virt/lib/python3.9/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/ThisAndThat/python/ml/mydata/virt/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/ThisAndThat/python/ml/mydata/virt/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File ~/ThisAndThat/python/ml/mydata/virt/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1550, in LinePlot._make_plot(self, fig)
#    1547 label = self._mark_right_label(label, index=i)
#    1548 kwds["label"] = label
# -> 1550 newlines = plotf(
#    1551     ax,
#    1552     x,
#    1553     y,
#    1554     style=style,
#    1555     column_num=i,
#    1556     stacking_id=stacking_id,
#    1557     is_errorbar=is_errorbar,
#    1558     **kwds,
#    1559 )
#    1560 self._append_legend_handles_labels(newlines[0], label)
#    1562 if self._is_ts_plot():
#    1563     # reset of xlim should be used for ts data
#    1564     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~/ThisAndThat/python/ml/mydata/virt/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1759, in AreaPlot._plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1757 if column_num == 0:
#    1758     cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1759 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
#    1761 # need to remove label, because subplots uses mpl legend as it is
#    1762 line_kwds = kwds.copy()
#
# File ~/ThisAndThat/python/ml/mydata/virt/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1660, in LinePlot._get_stacked_values(cls, ax, stacking_id, values, label)
#    1653 elif (values <= 0).all():
#    1654     # TODO #54485
#    1655     return (
#    1656         ax._stacker_neg_prior[stacking_id]  # type: ignore[attr-defined]
#    1657         + values
#    1658     )
# -> 1660 raise ValueError(
#    1661     "When stacked is True, each column must be either "
#    1662     "all positive or all negative. "
#    1663     f"Column '{label}' contains both positive and negative values"
#    1664 )
#
# ValueError: When stacked is True, each column must be either all positive or all negative. Column 'Mon' contains both positive and negative values
